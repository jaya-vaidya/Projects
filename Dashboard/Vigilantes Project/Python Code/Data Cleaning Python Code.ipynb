# %%
import csv
import pandas as pd

# %%
filename = "Police_Department_Incident_Reports__2018_to_Present.csv"

# %%
data = pd.read_csv(filename, header=0)
df = pd.DataFrame(data)
df.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2018/09/16 02:00:00 PM    2018/09/16         14:00           2018
# 1  2018/09/16 06:40:00 PM    2018/09/16         18:40           2018
# 2  2018/09/23 01:00:00 AM    2018/09/23         01:00           2018
# 3  2018/09/20 05:00:00 PM    2018/09/20         17:00           2018
# 4  2018/09/21 11:00:00 PM    2018/09/21         23:00           2018
#
#   Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 0               Sunday  2018/09/16 06:07:00 PM  71833409320       718334
# 1               Sunday  2018/09/16 07:27:00 PM  71833528150       718335
# 2               Sunday  2018/09/23 05:30:00 PM  71849106224       718491
# 3             Thursday  2018/09/23 10:24:00 PM  71889071000       718890
# 4               Friday  2018/09/22 02:05:00 PM  71897971000       718979
#
#    Incident Number  CAD Number  ...    \
# 0        186217539         NaN  ...
# ...

# %%
filtered_df = df[df['Latitude'].notnull()]
filtered_df = filtered_df[filtered_df['Longitude'].notnull()]

# %%
filtered_df.head(10)
# Out:
#          Incident Datetime Incident Date Incident Time  Incident Year  \
# 5   2018/08/20 07:45:00 AM    2018/08/20         07:45           2018
# 6   2018/08/11 07:10:00 PM    2018/08/11         19:10           2018
# 7   2018/08/14 02:15:00 PM    2018/08/14         14:15           2018
# 8   2018/08/14 03:07:00 PM    2018/08/14         15:07           2018
# 9   2018/08/14 03:07:00 PM    2018/08/14         15:07           2018
# 10  2018/08/10 05:20:00 AM    2018/08/10         05:20           2018
# 11  2018/08/19 11:20:00 PM    2018/08/19         23:20           2018
# 12  2018/08/21 10:43:00 AM    2018/08/21         10:43           2018
# 13  2018/08/15 04:40:00 PM    2018/08/15         16:40           2018
# 14  2018/08/17 11:17:00 PM    2018/08/17         23:17           2018
#
#    Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 5                Monday  2018/08/20 07:45:00 AM  70509301003       705093
# ...

# %%
filtered_df.count()
# Out:
# Incident Datetime          10142
# Incident Date              10142
# Incident Time              10142
# Incident Year              10142
# Incident Day of Week       10142
# Report Datetime            10142
# Row ID                     10142
# Incident ID                10142
# Incident Number            10142
# CAD Number                  7814
# Report Type Code           10142
# Report Type Description    10142
# Filed Online                2254
# Incident Code              10142
# Incident Category          10142
# Incident Subcategory       10142
# Incident Description       10142
# Resolution                 10142
# Intersection               10142
# CNN                        10142
# Police District            10142
# Analysis Neighborhood      10135
# Supervisor District        10142
# Latitude                   10142
# Longitude                  10142
# point                      10142
# dtype: int64

# %%
Zipcode = {'Inner Sunset': 94122, 'Japantown': 94115, 'Lakeshore' : 94132, 'Lincoln Park':94121, 'Lone Mountain/USF':94117,
            'Marina':94123, 'McLaren Park':94134, 'Mission':94110, 'Mission Bay':94107, 'Bayview Hunters Point':94124, 
           'Bernal Heights': 94110, 'Castro/Upper Market': 94114, 'Chinatown': 94108, 'Excelsior': 94112, 
           'Financial District/South Beach': 94104, 'Glen Park': 94131, 'Golden Gate Park': 94121, 'Haight Ashbury': 94117, 
           'Hayes Valley': 94102, 'Inner Richmond': 94118, 'Nob Hill': 94109, 'Noe Valley': 94114,'North Beach': 94133,
           'Oceanview/Merced/Ingleside' :94112, 'Outer Mission': 94112, 'Outer Richmond': 94121, 'Pacific Heights': 94115, 
           'Portola': 94134, 'Potrero Hill': 94107, 'Presidio': 94129, 'Presidio Heights': 94118, 'Russian Hill': 94109, 'Seacliff': 94121, 
           'South of Market': 94103, 'Sunset/Parkside': 94116, 'Tenderloin': 94102, 'Treasure Island': 94130, 'Twin Peaks': 94131, 
           'Visitacion Valley': 94134, 'West of Twin Peaks': 94127, 'Western Addition': 94115}
filtered_df["Zip"] = filtered_df["Analysis Neighborhood"].map(Zipcode)
filtered_df.tail(20)
# Out:
#             Incident Datetime Incident Date Incident Time  Incident Year  \
# 10661  2018/10/22 07:30:00 PM    2018/10/22         19:30           2018
# 10662  2018/10/22 08:20:00 PM    2018/10/22         20:20           2018
# 10663  2018/10/22 06:10:00 PM    2018/10/22         18:10           2018
# 10664  2018/10/22 04:46:00 PM    2018/10/22         16:46           2018
# 10665  2018/10/22 07:20:00 PM    2018/10/22         19:20           2018
# 10666  2018/10/22 06:00:00 PM    2018/10/22         18:00           2018
# 10667  2018/10/22 08:35:00 PM    2018/10/22         20:35           2018
# 10668  2018/10/22 12:10:00 AM    2018/10/22         00:10           2018
# 10669  2018/10/22 06:23:00 PM    2018/10/22         18:23           2018
# 10670  2018/10/22 07:32:00 PM    2018/10/22         19:32           2018
# 10671  2018/10/18 02:00:00 PM    2018/10/18         14:00           2018
# 10672  2018/10/22 07:55:00 PM    2018/10/22         19:55           2018
# ...

# %%
filtered_df.to_csv('crime_cleandata.csv')
